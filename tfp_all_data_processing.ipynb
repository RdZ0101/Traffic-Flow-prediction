# %%
import math
import warnings
import numpy as np
import pandas as pd
import sklearn.metrics as metrics
import matplotlib as mpl
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

warnings.filterwarnings("ignore")
print(tf.__version__)
# Out:
# 2.17.0

# %% [markdown]
# # Data Pre-processing

# %%
raw = pd.read_csv("scats-10-2006.csv")
raw.describe()
# Out:
#        SCATS Number  NB_LATITUDE  NB_LONGITUDE  HF VicRoads Internal  \
# count   4192.000000  4192.000000   4192.000000           4192.000000
# mean    3639.151718   -37.542437    143.985065          10234.837786
# std      805.584115     3.240889     12.429455           5579.371363
# min      970.000000   -37.867600      0.000000             -1.000000
# 25%     3122.000000   -37.833120    145.036169           5887.000000
# 50%     4032.000000   -37.822846    145.058038          10074.000000
# 75%     4263.000000   -37.808920    145.077826          16149.000000
# max     4821.000000     0.000000    145.098850          20314.000000
#
#        VR Internal Stat  VR Internal Loc  NB_TYPE_SURVEY          V00  \
# count       4192.000000      4192.000000          4192.0  4192.000000
# mean         819.153626         4.252147             1.0    34.049380
# std          628.218870         2.194029             0.0    28.438688
# min          182.000000         1.000000             1.0     0.000000
# 25%          380.000000         3.000000             1.0    15.000000
# 50%          650.000000         5.000000             1.0    26.000000
# 75%          950.000000         7.000000             1.0    44.000000
# max         2707.000000         8.000000             1.0   304.000000
#
#                V01          V02  ...          V86          V87          V88  \
# count  4192.000000  4192.000000  ...  4192.000000  4192.000000  4192.000000
# mean     30.185592    25.936307  ...    76.283874    73.049380    72.192748
# std      26.565710    24.243348  ...    37.577091    36.049374    36.669158
# min       0.000000     0.000000  ...     0.000000     0.000000     0.000000
# 25%      12.000000    10.000000  ...    51.000000    48.000000    46.000000
# 50%      22.000000    18.000000  ...    70.000000    67.000000    66.000000
# 75%      39.000000    33.000000  ...    97.000000    95.000000    93.000000
# max     252.000000   201.000000  ...   334.000000   259.000000   275.000000
#
#                V89          V90          V91          V92          V93  \
# count  4192.000000  4192.000000  4192.000000  4192.000000  4192.000000
# mean     65.655057    61.398378    56.124761    52.262643    45.383111
# std      33.885956    33.121580    32.505183    33.070764    30.096586
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      42.000000    37.000000    33.000000    29.000000    24.000000
# 50%      60.000000    55.000000    50.000000    45.000000    39.000000
# 75%      85.000000    81.000000    74.000000    68.000000    59.000000
# max     275.000000   231.000000   256.000000   324.000000   221.000000
#
#                V94          V95
# count  4192.000000  4192.000000
# mean     40.827529    35.408158
# std      30.012899    27.518453
# min       0.000000     0.000000
# 25%      20.000000    17.000000
# 50%      33.000000    28.000000
# 75%      53.000000    46.000000
# max     279.000000   212.000000
#
# [8 rows x 103 columns]

# %% [markdown]
# We have 4192 values to work with.
#
# Let's first, based on description, decide what data will be relevant:
#
# - **SCATS Number**: ID of the intersection. We will be using this as part of our predictor.
# - **Location**: Direction of the intersection. Will be hard to use this, so discard.
# - **CD_MELWAY**: Essentially same as SCATS number, but in a harder to use form. Discard.
# - **NB_LATITUDE, NB_LONGITUDE**: Coordinates of the intersection. Changes depending on direction (N, E, S, W, etc). For now, maybe not relevant, so discard
# - **HF VicRoads Internal**: This seems to point to specific intersection exits. Could be useful?
# - **VR Internal Stat/Loc**: Internal Stat seems to point to intersections, while Loc seems to point in cardinal directions as a numeral. Stat represents the same data as SCATS number, but Loc could be useful? (Similar to HF VicRoads Internal)
# - **NB_TYPE_SURVEY**: Same for every entry, discard.
# - **Date**: Date in dd/MM/YYYY format. As this data is only for October of 2006, the actual date might not be useful. We can try representing this as day of the week instead? This might yield more meaningful results.
# - **V00 - V95**: describes times from 00:00 - 23:45, in 15-minute intervals. This is what we will use as a predictor.

# %%
raw.head()
# Out:
#    SCATS Number                         Location CD_MELWAY  NB_LATITUDE  \
# 0           970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# 1           970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# 2           970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# 3           970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
# 4           970  WARRIGAL_RD N of HIGH STREET_RD   060 G10    -37.86703
#
#    NB_LONGITUDE  HF VicRoads Internal  VR Internal Stat  VR Internal Loc  \
# 0     145.09159                   249               182                1
# 1     145.09159                   249               182                1
# 2     145.09159                   249               182                1
# 3     145.09159                   249               182                1
# 4     145.09159                   249               182                1
#
#    NB_TYPE_SURVEY       Date  ...  V86  V87  V88  V89  V90  V91  V92  V93  \
# 0               1  1/10/2006  ...  114   97   97   66   81   50   59   47
# 1               1  2/10/2006  ...  111  102  107  114   80   60   62   48
# 2               1  3/10/2006  ...  130  132  114   86   93   90   73   57
# 3               1  4/10/2006  ...  115  113  132  101  113   90   78   66
# 4               1  5/10/2006  ...  171  120  116  113   99   91   61   55
#
#    V94  V95
# 0   29   34
# 1   44   26
# 2   29   40
# 3   52   44
# 4   49   36
#
# [5 rows x 106 columns]

# %% [markdown]
# For a preliminary training run, we will focus on data from only one intersection.

# %%
# Drop the fields we've decided to discard
df = raw.drop(["NB_LATITUDE", "NB_LONGITUDE", "CD_MELWAY", 
                 "Location", "HF VicRoads Internal", "VR Internal Stat", 
                 "VR Internal Loc", "NB_TYPE_SURVEY"], axis=1)
df.head()
# Out:
#    SCATS Number       Date  V00  V01  V02  V03  V04  V05  V06  V07  ...  V86  \
# 0           970  1/10/2006   86   83   52   58   59   44   31   37  ...  114
# 1           970  2/10/2006   32   28   17   11    7   11    6   15  ...  111
# 2           970  3/10/2006   26   32   21   14   10   12   13   10  ...  130
# 3           970  4/10/2006   32   22   28   13   16    8   14   10  ...  115
# 4           970  5/10/2006   40   39   21   11   16    9   15   15  ...  171
#
#    V87  V88  V89  V90  V91  V92  V93  V94  V95
# 0   97   97   66   81   50   59   47   29   34
# 1  102  107  114   80   60   62   48   44   26
# 2  132  114   86   93   90   73   57   29   40
# 3  113  132  101  113   90   78   66   52   44
# 4  120  116  113   99   91   61   55   49   36
#
# [5 rows x 98 columns]

# %% [markdown]
# Our time of day is scattered, so let's convert the V00 - V95 columns into their own rows with a new column: 'V', which will represent the 15-minute increment to predict. Date will be replaced with day of the week.

# %%
import datetime

# parse d/MM/YYYY format to DateTime
def parse_date(date_string):
    split = date_string.split('/')

    if len(split) != 3:
        print(f"invalid date format: {date_string}")

    day = int(split[0])
    month = int(split[1])
    year = int(split[2])

    return datetime.datetime(year, month, day)

# %%
def append_v(n):
    if n < 10:
        column_name = "V0" + str(n)
    else:
        column_name = "V" + str(n)
        
    return column_name

# %%
unique_scats = df['SCATS Number'].unique()
print(f"{len(unique_scats)} unique SCATS numbers.")
# Out:
# 40 unique SCATS numbers.

# %%
for scats_n in unique_scats:
    print(f"Processing SCATS Number: {scats_n}")
    
    data = []
    
    for index, row in df[df['SCATS Number'] == scats_n].iterrows():
        for i in range(0, 96):
            col = append_v(i)
            data.append(row[col])

    processed = pd.DataFrame(data, columns=['VFlow'])

    row_split = int(processed.shape[0] * 0.7)
    print(row_split) 
    train_dataset = processed[:row_split]
    test_dataset = processed[row_split:]

    train_filename = f"intersection/train/train_{scats_n}.csv"
    test_filename = f"intersection/test/test_{scats_n}.csv"
    
    train_dataset.to_csv(train_filename, index=False)
    test_dataset.to_csv(test_filename, index=False)
    
    print(f"Saved train data to {train_filename} and test data to {test_filename}")
# Out:
# Processing SCATS Number: 970
# 8265
# Saved train data to intersection/train/train_970.csv and test data to intersection/test/test_970.csv
# Processing SCATS Number: 2000
# 7660
# Saved train data to intersection/train/train_2000.csv and test data to intersection/test/test_2000.csv
# Processing SCATS Number: 2200
# 8332
# Saved train data to intersection/train/train_2200.csv and test data to intersection/test/test_2200.csv
# Processing SCATS Number: 2820
# 4099
# Saved train data to intersection/train/train_2820.csv and test data to intersection/test/test_2820.csv
# Processing SCATS Number: 2825
# 2083
# Saved train data to intersection/train/train_2825.csv and test data to intersection/test/test_2825.csv
# Processing SCATS Number: 2827
# 8332
# Saved train data to intersection/train/train_2827.csv and test data to intersection/test/test_2827.csv
# Processing SCATS Number: 2846
# 8332
# Saved train data to intersection/train/train_2846.csv and test data to intersection/test/test_2846.csv
# Processing SCATS Number: 3001
# 6384
# Saved train data to intersection/train/train_3001.csv and test data to intersection/test/test_3001.csv
# Processing SCATS Number: 3002
# 6988
# Saved train data to intersection/train/train_3002.csv and test data to intersection/test/test_3002.csv
# Processing SCATS Number: 3120
# 8332
# Saved train data to intersection/train/train_3120.csv and test data to intersection/test/test_3120.csv
# Processing SCATS Number: 3122
# 6249
# Saved train data to intersection/train/train_3122.csv and test data to intersection/test/test_3122.csv
# Processing SCATS Number: 3126
# 6249
# Saved train data to intersection/train/train_3126.csv and test data to intersection/test/test_3126.csv
# Processing SCATS Number: 3127
# 5241
# Saved train data to intersection/train/train_3127.csv and test data to intersection/test/test_3127.csv
# Processing SCATS Number: 3180
# 6249
# Saved train data to intersection/train/train_3180.csv and test data to intersection/test/test_3180.csv
# Processing SCATS Number: 3662
# 8332
# Saved train data to intersection/train/train_3662.csv and test data to intersection/test/test_3662.csv
# Processing SCATS Number: 3682
# 7795
# Saved train data to intersection/train/train_3682.csv and test data to intersection/test/test_3682.csv
# Processing SCATS Number: 3685
# 5577
# Saved train data to intersection/train/train_3685.csv and test data to intersection/test/test_3685.csv
# Processing SCATS Number: 3804
# 8332
# Saved train data to intersection/train/train_3804.csv and test data to intersection/test/test_3804.csv
# Processing SCATS Number: 3812
# 8332
# Saved train data to intersection/train/train_3812.csv and test data to intersection/test/test_3812.csv
# Processing SCATS Number: 4030
# 6249
# Saved train data to intersection/train/train_4030.csv and test data to intersection/test/test_4030.csv
# Processing SCATS Number: 4032
# 8332
# Saved train data to intersection/train/train_4032.csv and test data to intersection/test/test_4032.csv
# Processing SCATS Number: 4034
# 8332
# Saved train data to intersection/train/train_4034.csv and test data to intersection/test/test_4034.csv
# Processing SCATS Number: 4035
# 8332
# Saved train data to intersection/train/train_4035.csv and test data to intersection/test/test_4035.csv
# Processing SCATS Number: 4040
# 12499
# Saved train data to intersection/train/train_4040.csv and test data to intersection/test/test_4040.csv
# Processing SCATS Number: 4043
# 8332
# Saved train data to intersection/train/train_4043.csv and test data to intersection/test/test_4043.csv
# Processing SCATS Number: 4051
# 6249
# Saved train data to intersection/train/train_4051.csv and test data to intersection/test/test_4051.csv
# Processing SCATS Number: 4057
# 8198
# Saved train data to intersection/train/train_4057.csv and test data to intersection/test/test_4057.csv
# Processing SCATS Number: 4063
# 8332
# Saved train data to intersection/train/train_4063.csv and test data to intersection/test/test_4063.csv
# Processing SCATS Number: 4262
# 1747
# Saved train data to intersection/train/train_4262.csv and test data to intersection/test/test_4262.csv
# Processing SCATS Number: 4263
# 6988
# Saved train data to intersection/train/train_4263.csv and test data to intersection/test/test_4263.csv
# Processing SCATS Number: 4264
# 7727
# Saved train data to intersection/train/train_4264.csv and test data to intersection/test/test_4264.csv
# Processing SCATS Number: 4266
# 8332
# Saved train data to intersection/train/train_4266.csv and test data to intersection/test/test_4266.csv
# Processing SCATS Number: 4270
# 8332
# Saved train data to intersection/train/train_4270.csv and test data to intersection/test/test_4270.csv
# Processing SCATS Number: 4272
# 6048
# Saved train data to intersection/train/train_4272.csv and test data to intersection/test/test_4272.csv
# Processing SCATS Number: 4273
# 4166
# Saved train data to intersection/train/train_4273.csv and test data to intersection/test/test_4273.csv
# Processing SCATS Number: 4321
# 8332
# Saved train data to intersection/train/train_4321.csv and test data to intersection/test/test_4321.csv
# Processing SCATS Number: 4324
# 6249
# Saved train data to intersection/train/train_4324.csv and test data to intersection/test/test_4324.csv
# Processing SCATS Number: 4335
# 4166
# Saved train data to intersection/train/train_4335.csv and test data to intersection/test/test_4335.csv
# Processing SCATS Number: 4812
# 5241
# Saved train data to intersection/train/train_4812.csv and test data to intersection/test/test_4812.csv
# Processing SCATS Number: 4821
# 8332
# Saved train data to intersection/train/train_4821.csv and test data to intersection/test/test_4821.csv

# %% [markdown]
# ## note: functions below this line are deprecated
# converts data straight to time lag form, which is NOT used by the repo, thus should be disregarded

# %%
lag = 6 

for scats_n in unique_scats:
    data = []
    
    for index, row in df[df['SCATS Number'] == scats_n].iterrows():
        for i in range(lag, 96):
            lag_cols = []
            for j in range(lag, 0, -1):
                lag_cols.append(append_v(i - j))
            col = append_v(i)
            
            data.append([row[lag_cols].values, row[col]])

    processed_lagged = pd.DataFrame(data, columns=[f'Last{lag}VFlow', 'VFlow'])
    
    processed_lagged_filename = f"intersection/processed/{scats_n}_processed.csv"
    processed_lagged.to_csv(processed_lagged_filename, index=False)
    
    print(f"Processed lagged data saved for SCATS {scats_n} to {processed_lagged_filename}")
# Out:
# Processed lagged data saved for SCATS 970 to intersection/processed/970_processed.csv
# Processed lagged data saved for SCATS 2000 to intersection/processed/2000_processed.csv
# Processed lagged data saved for SCATS 2200 to intersection/processed/2200_processed.csv
# Processed lagged data saved for SCATS 2820 to intersection/processed/2820_processed.csv
# Processed lagged data saved for SCATS 2825 to intersection/processed/2825_processed.csv
# Processed lagged data saved for SCATS 2827 to intersection/processed/2827_processed.csv
# Processed lagged data saved for SCATS 2846 to intersection/processed/2846_processed.csv
# Processed lagged data saved for SCATS 3001 to intersection/processed/3001_processed.csv
# Processed lagged data saved for SCATS 3002 to intersection/processed/3002_processed.csv
# Processed lagged data saved for SCATS 3120 to intersection/processed/3120_processed.csv
# Processed lagged data saved for SCATS 3122 to intersection/processed/3122_processed.csv
# Processed lagged data saved for SCATS 3126 to intersection/processed/3126_processed.csv
# Processed lagged data saved for SCATS 3127 to intersection/processed/3127_processed.csv
# Processed lagged data saved for SCATS 3180 to intersection/processed/3180_processed.csv
# Processed lagged data saved for SCATS 3662 to intersection/processed/3662_processed.csv
# Processed lagged data saved for SCATS 3682 to intersection/processed/3682_processed.csv
# Processed lagged data saved for SCATS 3685 to intersection/processed/3685_processed.csv
# Processed lagged data saved for SCATS 3804 to intersection/processed/3804_processed.csv
# Processed lagged data saved for SCATS 3812 to intersection/processed/3812_processed.csv
# Processed lagged data saved for SCATS 4030 to intersection/processed/4030_processed.csv
# Processed lagged data saved for SCATS 4032 to intersection/processed/4032_processed.csv
# Processed lagged data saved for SCATS 4034 to intersection/processed/4034_processed.csv
# Processed lagged data saved for SCATS 4035 to intersection/processed/4035_processed.csv
# Processed lagged data saved for SCATS 4040 to intersection/processed/4040_processed.csv
# Processed lagged data saved for SCATS 4043 to intersection/processed/4043_processed.csv
# Processed lagged data saved for SCATS 4051 to intersection/processed/4051_processed.csv
# Processed lagged data saved for SCATS 4057 to intersection/processed/4057_processed.csv
# Processed lagged data saved for SCATS 4063 to intersection/processed/4063_processed.csv
# Processed lagged data saved for SCATS 4262 to intersection/processed/4262_processed.csv
# Processed lagged data saved for SCATS 4263 to intersection/processed/4263_processed.csv
# Processed lagged data saved for SCATS 4264 to intersection/processed/4264_processed.csv
# Processed lagged data saved for SCATS 4266 to intersection/processed/4266_processed.csv
# Processed lagged data saved for SCATS 4270 to intersection/processed/4270_processed.csv
# Processed lagged data saved for SCATS 4272 to intersection/processed/4272_processed.csv
# Processed lagged data saved for SCATS 4273 to intersection/processed/4273_processed.csv
# Processed lagged data saved for SCATS 4321 to intersection/processed/4321_processed.csv
# Processed lagged data saved for SCATS 4324 to intersection/processed/4324_processed.csv
# Processed lagged data saved for SCATS 4335 to intersection/processed/4335_processed.csv
# Processed lagged data saved for SCATS 4812 to intersection/processed/4812_processed.csv
# Processed lagged data saved for SCATS 4821 to intersection/processed/4821_processed.csv
